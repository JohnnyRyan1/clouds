# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""

Predict future albedo using empirical albedo model and 2015-2100 temperature data.

"""

# Import modules
import numpy as np
import xarray as xr
import pandas as pd
import netCDF4
from scipy import stats
import glob
import pathlib
import os
import matplotlib.pyplot as plt

# %%
# Define path
path = '/Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/'

# Define savepath
sp = '/Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/'

# %%
# Define summer albedo and temp data
ds1 = xr.open_dataset(path + 'temp_albedo_summer_climatologies.nc')

# Define CMIP6 data
cmip_files = sorted(glob.glob(path + 'cmip6-summer-resampled/*/*.nc'))

# Define empirical model
model = pd.read_csv(path + 'empirical_albedo_model.csv')

# Define cloud fraction
cloud_file = netCDF4.Dataset(path + 'modis_cloud_properties/cloud_fraction_2010.nc')
cloud_fraction = cloud_file.variables['cloud_fraction'][:]

# Define 2.5 K bins
bins = np.arange(-7.5, 20, 2.5)

# Define reference grids for the 2015-2020 period
clrsky_albedo = np.mean(ds1['albedo'][:,:,12:], axis=2)

# Convert clear-sky albedo to all-sky albedo
correction = cloud_fraction * 5.0
reference_albedo = clrsky_albedo + correction

# %%
for j in range(len(cmip_files)):
    
    print('Processing %i out of %i' %(j+1, len(cmip_files)))
         
    # Read model
    cmip = xr.open_dataset(cmip_files[j])

    # Get some file names
    p = pathlib.Path(cmip_files[j])
    folder = p.parent.name
    savepath = sp + folder + '/' + p.name

    # Define reference grid for CMIP!!! 2015-2020 period
    reference_temp = np.mean(cmip['t2m'][:,:,:6], axis=2)
    reference_temp = reference_temp.where(reference_temp != -999)
    reference_temp = reference_temp.where(ds1['mask'] != 0)

    # Define empty array
    predicted_albedo = np.zeros((cmip['t2m'].shape[0], cmip['t2m'].shape[1]))

    for year in range(cmip['t2m'].shape[2]):

        # Normalize temperature to find bins
        summer_temp = cmip['t2m'][:,:,year].where(cmip['t2m'][:,:,year] != -999)
        normalized_temp = summer_temp - np.nanmean(reference_temp)

        # Find temperature difference
        temp_diff = summer_temp - reference_temp

        # Define empty array
        predicted_albedo_stack = np.zeros(temp_diff.shape)

        for i in range(len(bins) - 1):

            # Mask
            mask = (normalized_temp > bins[i]) & (normalized_temp < bins[i+1])

            # Stack
            predicted_albedo_stack = np.dstack((predicted_albedo_stack, reference_albedo + temp_diff.where(mask == 1) * model.iloc[i]['slope']))

        predicted_albedo_year = np.nansum(predicted_albedo_stack, axis=2)

        # Convert 0 to NaNs
        predicted_albedo_year[predicted_albedo_year == 0] = np.nan

        # Convert values < 0.3
        predicted_albedo_year[predicted_albedo_year < 30] = 30

        # Stack
        predicted_albedo = np.dstack((predicted_albedo, predicted_albedo_year))

    predicted_albedo = predicted_albedo[:,:,1:]

    # Save as NetCDF
    dataset = netCDF4.Dataset(savepath, 'w', format='NETCDF4_CLASSIC')
    print('Creating... %s' % savepath)
    dataset.Title = "Predicted albedo to 2100 based on summer 2 m air temperature"
    import time
    dataset.History = "Created " + time.ctime(time.time())
    dataset.Projection = "WGS 84"
    dataset.Reference = "Ryan, J. C., Smith. L. C., Cooley, S. W., and Pearson, B. (in review), Emerging importance of clouds for Greenland Ice Sheet energy balance and meltwater production."
    dataset.Contact = "jryan4@uoregon.edu"

    # Create new dimensions
    lat_dim = dataset.createDimension('y', predicted_albedo.shape[0])
    lon_dim = dataset.createDimension('x', predicted_albedo.shape[1])
    data_dim = dataset.createDimension('z', predicted_albedo.shape[2])

    # Define variable types
    Y = dataset.createVariable('latitude', np.float32, ('y', 'x'))
    X = dataset.createVariable('longitude', np.float32, ('y', 'x'))

    # Define units
    Y.units = "degrees"
    X.units = "degrees"

    # Create the actual 3D variable
    albedo_nc = dataset.createVariable('albedo', np.float32, ('y','x','z'))

    # Write data to layers
    Y[:] = ds1['latitude']
    X[:] = ds1['longitude']
    albedo_nc[:] = predicted_albedo

    print('Writing data to %s' % savepath)

    # Close dataset
    dataset.close()
# Out:
# Processing 1 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_ACCESS-CM2_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_ACCESS-CM2_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 2 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_ACCESS-ESM1-5_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_ACCESS-ESM1-5_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 3 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CESM2-WACCM_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CESM2-WACCM_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 4 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CESM2_Amon_ssp126_r4i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CESM2_Amon_ssp126_r4i1p1f1_tas_2015-2100.nc
# Processing 5 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CMCC-CM2-SR5_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CMCC-CM2-SR5_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 6 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CNRM-CM6-1-HR_Amon_ssp126_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CNRM-CM6-1-HR_Amon_ssp126_r1i1p1f2_tas_2015-2100.nc
# Processing 7 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CNRM-CM6-1_Amon_ssp126_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CNRM-CM6-1_Amon_ssp126_r1i1p1f2_tas_2015-2100.nc
# Processing 8 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CNRM-ESM2-1_Amon_ssp126_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CNRM-ESM2-1_Amon_ssp126_r1i1p1f2_tas_2015-2100.nc
# Processing 9 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CanESM5-CanOE_Amon_ssp126_r1i1p2f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CanESM5-CanOE_Amon_ssp126_r1i1p2f1_tas_2015-2100.nc
# Processing 10 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CanESM5_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_CanESM5_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 11 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_EC-Earth3-Veg_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_EC-Earth3-Veg_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 12 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_EC-Earth3_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_EC-Earth3_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 13 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_GFDL-ESM4_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_GFDL-ESM4_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 14 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_GISS-E2-1-G_Amon_ssp126_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_GISS-E2-1-G_Amon_ssp126_r1i1p1f2_tas_2015-2100.nc
# Processing 15 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_INM-CM4-8_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_INM-CM4-8_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 16 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_INM-CM5-0_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_INM-CM5-0_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 17 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_IPSL-CM6A-LR_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_IPSL-CM6A-LR_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 18 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_KACE-1-0-G_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_KACE-1-0-G_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 19 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_MIROC-ES2L_Amon_ssp126_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_MIROC-ES2L_Amon_ssp126_r1i1p1f2_tas_2015-2100.nc
# Processing 20 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_MIROC6_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_MIROC6_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 21 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_MPI-ESM1-2-HR_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_MPI-ESM1-2-HR_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 22 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_MPI-ESM1-2-LR_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_MPI-ESM1-2-LR_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 23 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_MRI-ESM2-0_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_MRI-ESM2-0_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 24 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_NorESM2-LM_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_NorESM2-LM_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 25 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_NorESM2-MM_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_NorESM2-MM_Amon_ssp126_r1i1p1f1_tas_2015-2100.nc
# Processing 26 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_UKESM1-0-LL_Amon_ssp126_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP126/CMIP6_UKESM1-0-LL_Amon_ssp126_r1i1p1f2_tas_2015-2100.nc
# Processing 27 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_ACCESS-CM2_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_ACCESS-CM2_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 28 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_ACCESS-ESM1-5_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_ACCESS-ESM1-5_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 29 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CESM2-WACCM_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CESM2-WACCM_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 30 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CESM2_Amon_ssp245_r4i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CESM2_Amon_ssp245_r4i1p1f1_tas_2015-2100.nc
# Processing 31 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CMCC-CM2-SR5_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CMCC-CM2-SR5_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 32 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CNRM-CM6-1-HR_Amon_ssp245_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CNRM-CM6-1-HR_Amon_ssp245_r1i1p1f2_tas_2015-2100.nc
# Processing 33 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CNRM-CM6-1_Amon_ssp245_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CNRM-CM6-1_Amon_ssp245_r1i1p1f2_tas_2015-2100.nc
# Processing 34 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CNRM-ESM2-1_Amon_ssp245_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CNRM-ESM2-1_Amon_ssp245_r1i1p1f2_tas_2015-2100.nc
# Processing 35 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CanESM5-CanOE_Amon_ssp245_r1i1p2f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CanESM5-CanOE_Amon_ssp245_r1i1p2f1_tas_2015-2100.nc
# Processing 36 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CanESM5_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_CanESM5_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 37 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_EC-Earth3-Veg_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_EC-Earth3-Veg_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 38 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_EC-Earth3_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_EC-Earth3_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 39 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_GFDL-ESM4_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_GFDL-ESM4_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 40 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_GISS-E2-1-G_Amon_ssp245_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_GISS-E2-1-G_Amon_ssp245_r1i1p1f2_tas_2015-2100.nc
# Processing 41 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_INM-CM4-8_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_INM-CM4-8_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 42 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_INM-CM5-0_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_INM-CM5-0_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 43 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_IPSL-CM6A-LR_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_IPSL-CM6A-LR_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 44 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_KACE-1-0-G_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_KACE-1-0-G_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 45 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_MIROC-ES2L_Amon_ssp245_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_MIROC-ES2L_Amon_ssp245_r1i1p1f2_tas_2015-2100.nc
# Processing 46 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_MIROC6_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_MIROC6_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 47 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_MPI-ESM1-2-HR_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_MPI-ESM1-2-HR_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 48 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_MPI-ESM1-2-LR_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_MPI-ESM1-2-LR_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 49 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_MRI-ESM2-0_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_MRI-ESM2-0_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 50 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_NorESM2-LM_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_NorESM2-LM_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 51 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_NorESM2-MM_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_NorESM2-MM_Amon_ssp245_r1i1p1f1_tas_2015-2100.nc
# Processing 52 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_UKESM1-0-LL_Amon_ssp245_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP245/CMIP6_UKESM1-0-LL_Amon_ssp245_r1i1p1f2_tas_2015-2100.nc
# Processing 53 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_ACCESS-CM2_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_ACCESS-CM2_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Processing 54 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_ACCESS-ESM1-5_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_ACCESS-ESM1-5_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Processing 55 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CESM2-WACCM_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CESM2-WACCM_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Processing 56 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CESM2_Amon_ssp585_r4i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CESM2_Amon_ssp585_r4i1p1f1_tas_2015-2100.nc
# Processing 57 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CMCC-CM2-SR5_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CMCC-CM2-SR5_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Processing 58 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CNRM-CM6-1-HR_Amon_ssp585_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CNRM-CM6-1-HR_Amon_ssp585_r1i1p1f2_tas_2015-2100.nc
# Processing 59 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CNRM-CM6-1_Amon_ssp585_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CNRM-CM6-1_Amon_ssp585_r1i1p1f2_tas_2015-2100.nc
# Processing 60 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CNRM-ESM2-1_Amon_ssp585_r1i1p1f2_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CNRM-ESM2-1_Amon_ssp585_r1i1p1f2_tas_2015-2100.nc
# Processing 61 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CanESM5-CanOE_Amon_ssp585_r1i1p2f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CanESM5-CanOE_Amon_ssp585_r1i1p2f1_tas_2015-2100.nc
# Processing 62 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CanESM5_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_CanESM5_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Processing 63 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_EC-Earth3-Veg_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_EC-Earth3-Veg_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Processing 64 out of 78
# Creating... /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_EC-Earth3_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Writing data to /Users/jryan4/Dropbox (University of Oregon)/research/clouds/data/cmip6-albedo/SSP585/CMIP6_EC-Earth3_Amon_ssp585_r1i1p1f1_tas_2015-2100.nc
# Processing 65 out of 78
